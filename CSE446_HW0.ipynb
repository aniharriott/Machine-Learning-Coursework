# %%
import numpy as np
import numpy.matlib as numpy
import matplotlib.pyplot as plt
import seaborn as sns

# 11.a
A = np.array([[0, 2, 4],[2, 4, 2],[3, 3, 1]])
X = np.linalg.inv(A)
print(X)
# Out:
# [[ 0.125 -0.625  0.75 ]
#  [-0.25   0.75  -0.5  ]
#  [ 0.375 -0.375  0.25 ]]

# %%
# 11.b
b = np.array([[-2],[-2],[-4]])
Xb = np.matmul(X, b)
print(Xb)
c = np.array([[1],[1],[1]])
Ac = np.matmul(A, c)
print(Ac)
# Out:
# [[-2.]
#  [ 1.]
#  [-1.]]
# [[6]
#  [8]
#  [7]]

# %%
# 12.a
n = 40000
Z = numpy.random.randn(n)
plt.step(sorted(Z), np.arange(1,n+1)/float(n), label = "Gaussian")
plt.xlim(-3, 3)
plt.ylim(0.0, 1.0)

sns.set()
plt.xlabel("Observations")
plt.ylabel("Probability")

# 12.b
plt.step(sorted(np.sum(np.sign(np.random.randn(n, 1))*np.sqrt(1./1), axis=1)), 
         np.arange(1,n+1)/float(n), label = "1")
plt.step(sorted(np.sum(np.sign(np.random.randn(n, 8))*np.sqrt(1./8), axis=1)), 
         np.arange(1,n+1)/float(n), label = "8")
plt.step(sorted(np.sum(np.sign(np.random.randn(n, 64))*np.sqrt(1./64), axis=1)), 
         np.arange(1,n+1)/float(n), label = "64")
plt.step(sorted(np.sum(np.sign(np.random.randn(n, 512))*np.sqrt(1./512), axis=1)), 
         np.arange(1,n+1)/float(n), label = "512")

plt.legend(loc="upper left")

# %%
import numpy as np
import numpy.matlib as numpy
import matplotlib.pyplot as plt
import seaborn as sns

# 11.a
A = np.array([[0, 2, 4],[2, 4, 2],[3, 3, 1]])
X = np.linalg.inv(A)
print(X)

# 11.b
b = np.array([[-2],[-2],[-4]])
Xb = np.matmul(X, b)
print(Xb)
c = np.array([[1],[1],[1]])
Ac = np.matmul(A, c)
print(Ac)

# 12.a
n = 40000
Z = numpy.random.randn(n)
plt.step(sorted(Z), np.arange(1,n+1)/float(n), label = "Gaussian")
plt.xlim(-3, 3)
plt.ylim(0.0, 1.0)

sns.set()
plt.xlabel("Observations")
plt.ylabel("Probability")

# 12.b
plt.step(sorted(np.sum(np.sign(np.random.randn(n, 1))*np.sqrt(1./1), axis=1)), 
    np.arange(1,n+1)/float(n), label = "1")
plt.step(sorted(np.sum(np.sign(np.random.randn(n, 8))*np.sqrt(1./8), axis=1)), 
    np.arange(1,n+1)/float(n), label = "8")
plt.step(sorted(np.sum(np.sign(np.random.randn(n, 64))*np.sqrt(1./64), axis=1)), 
    np.arange(1,n+1)/float(n), label = "64")
plt.step(sorted(np.sum(np.sign(np.random.randn(n, 512))*np.sqrt(1./512), axis=1)), 
    np.arange(1,n+1)/float(n), label = "512")

plt.legend(loc="upper left")
# Out:
# [[ 0.125 -0.625  0.75 ]
#  [-0.25   0.75  -0.5  ]
#  [ 0.375 -0.375  0.25 ]]
# [[-2.]
#  [ 1.]
#  [-1.]]
# [[6]
#  [8]
#  [7]]
